# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("crime.csv")
mvardf=df[df['OFFENSE_CODE_GROUP'].str.contains("Motor Vehicle Accident Response")]
mvardf
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0           I192064208          3831  Motor Vehicle Accident Response
# 8           I192064185          3811  Motor Vehicle Accident Response
# 17          I192064176          3831  Motor Vehicle Accident Response
# 18          I192064175          3801  Motor Vehicle Accident Response
# 22          I192064169          3801  Motor Vehicle Accident Response
# ...                ...           ...                              ...
# 412537      I152049517          3807  Motor Vehicle Accident Response
# 412541      I152049505          3803  Motor Vehicle Accident Response
# 412542      I152049504          3801  Motor Vehicle Accident Response
# 412546      I152049499          3801  Motor Vehicle Accident Response
# 412547      I152049497          3803  Motor Vehicle Accident Response
#
#                                  OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0              M/V - LEAVING SCENE - PROPERTY DAMAGE      C11            254
# 8       M/V ACCIDENT - INVOLVING BICYCLE - NO INJURY       A1            108
# 17             M/V - LEAVING SCENE - PROPERTY DAMAGE      E18            501
# 18                              M/V ACCIDENT - OTHER       A1             85
# 22                              M/V ACCIDENT - OTHER      E18            525
# ...                                              ...      ...            ...
# 412537             M/V ACCIDENT - OTHER CITY VEHICLE       D4            170
# 412541                M/V ACCIDENT - PERSONAL INJURY       D4            270
# 412542                          M/V ACCIDENT - OTHER       D4            154
# 412546                          M/V ACCIDENT - OTHER      E18            490
# 412547                M/V ACCIDENT - PERSONAL INJURY       E5            564
#
#        SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0           NaN  2019-08-15 22:08:00  2019      8    Thursday    22
# 8           NaN  2019-08-15 20:19:00  2019      8    Thursday    20
# 17          NaN  2019-08-15 19:29:00  2019      8    Thursday    19
# 18          NaN  2019-08-15 14:33:00  2019      8    Thursday    14
# 22          NaN  2019-08-15 19:20:00  2019      8    Thursday    19
# ...         ...                  ...   ...    ...         ...   ...
# 412537      NaN  2015-06-15 09:05:00  2015      6      Monday     9
# 412541      NaN  2015-06-15 08:33:00  2015      6      Monday     8
# 412542      NaN  2015-06-15 07:34:00  2015      6      Monday     7
# 412546      NaN  2015-06-15 07:31:00  2015      6      Monday     7
# 412547      NaN  2015-06-15 07:10:00  2015      6      Monday     7
#
#           UCR_PART          STREET        Lat       Long  \
# 0       Part Three  DORCHESTER AVE  42.308547 -71.058212
# 8       Part Three     CONGRESS ST  42.355628 -71.055677
# 17      Part Three   HYDE PARK AVE  42.280854 -71.118802
# 18      Part Three     ENDICOTT ST  42.364849 -71.057360
# 22      Part Three   HYDE PARK AVE  42.238510 -71.132779
# ...            ...             ...        ...        ...
# 412537  Part Three   WASHINGTON ST  42.337444 -71.075636
# 412541  Part Three    HARRISON AVE  42.332102 -71.079283
# 412542  Part Three     W NEWTON ST  42.342259 -71.077497
# 412546  Part Three     CUMMINS HWY  42.275316 -71.110819
# 412547  Part Three   WASHINGTON ST  42.294924 -71.119107
#
#                            Location
# 0       (42.30854728, -71.05821219)
# 8       (42.35562813, -71.05567739)
# 17      (42.28085355, -71.11880157)
# 18      (42.36484926, -71.05736028)
# 22      (42.23850959, -71.13277923)
# ...                             ...
# 412537  (42.33744400, -71.07563631)
# 412541  (42.33210200, -71.07928300)
# 412542  (42.34225888, -71.07749696)
# 412546  (42.27531600, -71.11081942)
# 412547  (42.29492396, -71.11910662)
#
# [48039 rows x 17 columns]

# %%
daycount=mvardf['DAY_OF_WEEK'].value_counts()
daycount
# Out:
# Friday       7611
# Saturday     7058
# Tuesday      6779
# Wednesday    6779
# Thursday     6691
# Monday       6618
# Sunday       6503
# Name: DAY_OF_WEEK, dtype: int64

# %%
mvardf['OFFENSE_CODE_GROUP'].value_counts()
# Out:
# Motor Vehicle Accident Response    48039
# Name: OFFENSE_CODE_GROUP, dtype: int64

# %%
days = daycount.index
count= daycount.values

fig, axs = plt.subplots(figsize=(10,7), sharey=True)
#axs.set_title("",loc="center")
axs.bar(days, count,color="coral")
axs.set_title("Motorvehicle accidents per day",fontsize =20)
axs.set_ylabel("number of motorvehicle accidents reported")
axs.set_xlabel("Days")
# Out:
# Text(0.5, 0, 'Days')
